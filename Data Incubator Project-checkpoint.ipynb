# %%
import pandas as pd
import numpy as np

# %%
dfd=pd.read_csv('Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv')
dfd.columns = pd.Series(dfd.columns).str.replace(' ','_')

# %%
dfd1=dfd[dfd.COMMUNITY_AREA_NAME != 'CHICAGO']

# %%
dfd2=dfd1.sort_values(['COMMUNITY_AREA_NAME'], ascending=True)

# %%
dfe=pd.read_csv('Energy_Usage_2010.csv')
dfe.columns = pd.Series(dfe.columns).str.replace(' ','_')

# %%
dfe1=dfe.groupby('COMMUNITY_AREA_NAME', as_index=False).sum()

# %%
df1=pd.concat([dfe1,dfd2],axis=1)

# %%
from bokeh.charts import Bar, show, output_file

p = Bar(dfe, 'COMMUNITY_AREA_NAME', values='TOTAL_KWH', agg='sum', title="Neighborhood Energy Use 2010", 
        legend=False, bar_width=1, color='#6495ed')
p.width=1200
p.height=500

output_file("bar1.html")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0c0cb4aa-1729-48e9-84ad-9bbceff35f87"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0c0cb4aa-1729-48e9-84ad-9bbceff35f87");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0c0cb4aa-1729-48e9-84ad-9bbceff35f87' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"78011b29-c2d6-424f-87d2-6d01e1fdc4bd":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"COMMUNITY_AREA_NAME":["Roseland"],"chart_index":[{"COMMUNITY_AREA_NAME":"Roseland"}],"color":["#6495ed"],"fill_alpha":[0.8],"height":[156021251.0],"label":[{"COMMUNITY_AREA_NAME":"Roseland"}],"line_alpha":[1.0],"line_color":["white"],"width":[1],"x":["Roseland"],"y":[78010625.5]}},"id":"dae0c966-06a4-4c6e-a61a-8d8b46c2c8fd","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"COMMUNITY_AREA_NAME":["Hyde Park"],"chart_index":[{"COMMUNITY_AREA_NAME":"Hyde Park"}],"color":["#6495ed"],"fill_alpha":[0.8],"height":[78510633.0],"label":[{"COMMUNITY_AREA_NAME":"Hyde Park"}],"line_alpha":[1.0],"line_color":["white"],"width":[1],"x":["Hyde Park"],"y":[39255316.5]}},"id":"08a6b328-399e-4414-a09d-9bd7df9dc0b6","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"COMMUNITY_AREA_NAME":["Edison Park"],"chart_index":[{"COMMUNITY_AREA_NAME":"Edison Park"}],"color":["#6495ed"],"fill_alpha":[0.8],"height":[43163570.0],"label":[{"COMMUNITY_AREA_NAME":"Edison Park"}],"line_alpha":[1.0],"line_color":["white"],"width":[1],"x":["Edison Park"],"y":[21581785.0]}},"id":"aa8270cf-ad4f-47b6-9dfe-a4ff30849152","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"472628c4-f000-4403-a250-684a892643ec","subtype":"Chart","type":"Plot"},"ticker":{"id":"a80abdea-b751-466b-a13b-0657934baa45","type":"BasicTicker"}},"id":"a0f6d22d-3bb3-4de1-b38f-d1fb6bf84f46","type":"Grid"},{"attributes":{"data_source":{"id":"aa8270cf-ad4f-47b6-9dfe-a4ff30849152","type":"ColumnDataSource"},"glyph":{"id":"3254f540-65e6-46cb-9ceb-a90798c645be","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b1fe22aa-51cc-427e-98f1-0c99d15b772e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"COMMUNITY_AREA_NAME":["Lincoln Square"],"chart_index":[{"COMMUNITY_AREA_NAME":"Lincoln Square"}],"color":["#6495ed"],"fill_alpha":[0.8],"height":[157750735.0],"label":[{"COMMUNITY_AREA_NAME":"Lincoln Square"}],"line_alpha":[1.0],"line_color":["white"],"width":[1],"x":["Lincoln Square"],"y":[78875367.5]}},"id":"b7241f79-1f66-4748-8a96-a69703b58f2e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"17c97ea8-2b26-4920-8881-d503c854aee9","type":"Rect"},{"attributes":{"data_source":{"id":"2bc85826-3a76-49af-83b4-e7e6167caf53","type":"ColumnDataSource"},"glyph":{"id":"e1c3caa8-5086-4259-ae72-b3cdddc53996","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"551aa8f5-ad4b-42b3-b92d-90e542f6b9c6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"COMMUNITY_AREA_NAME":["McKinley Park"],"chart_index":[{"COMMUNITY_AREA_NAME":"McKinley Park"}],"color":["#6495ed"],"fill_alpha":[0.8],"height":[58250739.0],"label":[{"COMMUNITY_AREA_NAME":"McKinley Park"}],"line_alpha":[1.0],"line_color":["white"],"width":[1],"x":["McKinley Park"],"y":[29125369.5]}},"id":"6125428e-52c0-415c-8938-e66ff118dc62","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"dbc7f132-452b-4106-aa80-e44866155e61","type":"ColumnDataSource"},"glyph":{"id":"314ccba4-a271-406a-8010-a6ff6ff1e579","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[1]</strong>&gt;</code></p>

# %%
dfs1=pd.concat([dfd2.COMMUNITY_AREA_NAME, dfd2.PER_CAPITA_INCOME_, dfe1.KWH_SQFT_MEAN_2010], axis=1)

# %%
dfs1.columns = ['Neighborhood', 'Per_Capita_Income', 'Energy_Per_SqFt']

# %%
from bokeh.charts import Scatter, output_file, show

p = Scatter(dfs1, x='Per_Capita_Income', y='Energy_Per_SqFt', title="Income vs. Energy Use",

            xlabel="Per Capita Income", ylabel="Energy Use (kWh) Per SqFt", color='#8B0000')

output_file("scatter1.html")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="631b4e22-fd4b-44c4-8beb-f6b8911ed71e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("631b4e22-fd4b-44c4-8beb-f6b8911ed71e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '631b4e22-fd4b-44c4-8beb-f6b8911ed71e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d17a2a55-a336-4fd0-a9bf-49c0ef84baed":{"roots":{"references":[{"attributes":{"axis_label":"Energy Use (kWh) Per SqFt","formatter":{"id":"c78c18e7-991f-47af-b86a-d11df179e199","type":"BasicTickFormatter"},"plot":{"id":"9cfc38e9-0826-4bf2-bbe9-bb0c7c963552","subtype":"Chart","type":"Plot"},"ticker":{"id":"a46c79f8-e409-4226-a23c-4772f912e98c","type":"BasicTicker"}},"id":"a29cca12-5293-466c-8922-0de98f956418","type":"LinearAxis"},{"attributes":{"axis_label":"Per Capita Income","formatter":{"id":"ac663c37-3d6a-43d2-aaec-690ca134dc9f","type":"BasicTickFormatter"},"plot":{"id":"9cfc38e9-0826-4bf2-bbe9-bb0c7c963552","subtype":"Chart","type":"Plot"},"ticker":{"id":"9ef3a050-642b-400c-ae09-d81f095da067","type":"BasicTicker"}},"id":"fd44b92c-eee2-4cdc-b69b-42164eb2f463","type":"LinearAxis"},{"attributes":{"data_source":{"id":"ab1a6742-4ae5-48f3-a5ea-b22b064c2b0a","type":"ColumnDataSource"},"glyph":{"id":"db605e87-3918-4dda-83e2-f2c609b98ae9","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e46877c7-2213-4122-90c7-0ddda2fb6d63","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5661282f-0ae2-464e-842b-36a456395138","type":"PanTool"},{"id":"3e5028e3-3962-4dc4-b574-91a75aa115df","type":"WheelZoomTool"},{"id":"c928daef-3de0-4185-be1b-a4ad3e96179e","type":"BoxZoomTool"},{"id":"7cf3f03d-a1b4-4e17-81aa-0d27572cb35b","type":"SaveTool"},{"id":"d074a141-c627-40c8-963b-7a96e4c089c4","type":"ResetTool"},{"id":"3ddb061d-ba10-4f6c-89aa-ea028c7c5d8d","type":"HelpTool"}]},"id":"00045af3-1964-4883-9c52-2eff0bf7ba5d","type":"Toolbar"},{"attributes":{"plot":null,"text":"Income vs. Energy Use"},"id":"6681529e-5da1-4352-8f84-313178482639","type":"Title"},{"attributes":{"plot":{"id":"9cfc38e9-0826-4bf2-bbe9-bb0c7c963552","subtype":"Chart","type":"Plot"}},"id":"5661282f-0ae2-464e-842b-36a456395138","type":"PanTool"},{"attributes":{"location":"top_left","plot":{"id":"9cfc38e9-0826-4bf2-bbe9-bb0c7c963552","subtype":"Chart","type":"Plot"}},"id":"1f7301e8-8f7e-4c50-a458-6449cd0fb60c","type":"Legend"},{"attributes":{},"id":"ac663c37-3d6a-43d2-aaec-690ca134dc9f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"9cfc38e9-0826-4bf2-bbe9-bb0c7c963552","subtype":"Chart","type":"Plot"}},"id":"7cf3f03d-a1b4-4e17-81aa-0d27572cb35b","type":"SaveTool"},{"attributes":{"plot":{"id":"9cfc38e9-0826-4bf2-bbe9-bb0c7c963552","subtype":"Chart","type":"Plot"}},"id":"3ddb061d-ba10-4f6c-89aa-ea028c7c5d8d","type":"HelpTool"},{"attributes":{"plot":{"id":"9cfc38e9-0826-4bf2-bbe9-bb0c7c963552","subtype":"Chart","type":"Plot"},"ticker":{"id":"9ef3a050-642b-400c-ae09-d81f095da067","type":"BasicTicker"}},"id":"b9d50715-60b1-4f7a-ab6e-c8c29ad9fc21","type":"Grid"},{"attributes":{"plot":{"id":"9cfc38e9-0826-4bf2-bbe9-bb0c7c963552","subtype":"Chart","type":"Plot"}},"id":"d074a141-c627-40c8-963b-7a96e4c089c4","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[23939,23040,35787,37524,57123,60058,71551,88669,40959,32875,27751,44164,26576,21323,24336,27249,26282,22014,15461,15089,20039,31908,13781,43198,15957,10934,12961,44689,12034,10402,16444,65526,59077,16148,23791,19252,10432,23472,35911,13785,39056,18672,19398,18881,24454,16579,12515,28887,17949,20588,14685,17104,16563,8201,22677,26353,16134,13089,16954,22694,12765,15754,12171,25113,16907,13231,11317,11888,17285,23482,15528,39523,19713,34381,27149,25828,33385],"y_values":[5504778.929999998,1916569.9399999978,2573690.6299999994,2105448.5799999973,4 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[1]</strong>&gt;</code></p>

# %%
dfe2=dfe[dfe.BUILDING_TYPE != 'Commercial']

# %%
dfe3=dfe2.groupby('COMMUNITY_AREA_NAME', as_index=False).sum()

# %%
dfp=(dfe3.TOTAL_KWH / dfe3.TOTAL_POPULATION)

# %%
dfp1=pd.concat([dfs1, dfp], axis=1)

# %%
dfp1.columns = ['Neighborhood', 'Per_Capita_Income','Energy_Per_SqFt', 'Energy_Use_Per_Person']

# %%
from bokeh.charts import Scatter, output_file, show

p = Scatter(dfp1, x='Per_Capita_Income', y='Energy_Use_Per_Person', title="Income vs. Househould Energy Use",

            xlabel="Per Capita Income", ylabel="Energy Use Per Residential Person", color='#8B0000')

output_file("scatter2.html")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="79c20428-a7ba-498a-9011-4f1ac072bebc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("79c20428-a7ba-498a-9011-4f1ac072bebc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '79c20428-a7ba-498a-9011-4f1ac072bebc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"18ef987c-9b4a-4520-a08c-60c524252800":{"roots":{"references":[{"attributes":{"axis_label":"Energy Use Per Residential Person","formatter":{"id":"43af5444-b04d-410d-8e79-fd8445cd8280","type":"BasicTickFormatter"},"plot":{"id":"7c0a6d10-4cca-4123-82b9-b44ccb4492ec","subtype":"Chart","type":"Plot"},"ticker":{"id":"7eb93373-b4e0-474c-917e-f0f98f12863d","type":"BasicTicker"}},"id":"9cf02107-2938-4853-91b9-4b7621b56ef1","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"